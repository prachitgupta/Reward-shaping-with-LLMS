# %%
import gymnasium as gym
import highway_env

# Agent
from stable_baselines3 import DQN


import sys
from tqdm.notebook import trange

from stable_baselines3 import DQN
import pprint
from matplotlib import pyplot as plt
import numpy as np
import joblib
from tqdm import trange
# Out:
# 2025-01-08 10:42:07.694014: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-08 10:42:07.738564: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-01-08 10:42:08.092372: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-08 10:42:09.195739: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
class MyHighwayEnv(gym.Env):
    def __init__(self, vehicleCount=10):
        super(MyHighwayEnv, self).__init__()
        # base setting
        self.vehicleCount = vehicleCount

        # environment setting
        self.config = {
            "observation": {
                "type": "Kinematics",
                "features": ["presence", "x", "y", "vx", "vy"],
                "absolute": True,
                "normalize": True,
                "vehicles_count": vehicleCount,
                "see_behind": True,
            },
            "action": {
                "type": "DiscreteMetaAction",
                "target_speeds": np.linspace(0, 32, 9),
            },
            "duration": 40,
            "vehicles_density": 2,
            "show_trajectories": True,
            "render_agent": True,
        }
        self.env = gym.make("highway-v0", config = self.config)
        self.action_space = self.env.action_space
        self.observation_space = gym.spaces.Box(
            low=-np.inf,high=np.inf,shape=(10,5),dtype=np.float32
        )

    def step(self, action):
        # Step the wrapped environment and capture all returned values
        obs, dqn_reward, done, truncated, info = self.env.step(action)
        ##reward shaping takes place
        Reward = 1 / (1 + np.exp(-dqn_reward))

        return obs, Reward, done, truncated, info

    def reset(self, **kwargs):
        obs = self.env.reset(**kwargs)
        return obs  # Make sure to return the observation

# %%
from stable_baselines3.common.vec_env import DummyVecEnv
env = MyHighwayEnv()

# %%
model = DQN('MlpPolicy', env,
            policy_kwargs=dict(net_arch=[256, 256]),
            learning_rate=5e-4,
            buffer_size=15000,
            learning_starts=200,
            batch_size=32,
            gamma=0.8,
            train_freq=1,
            gradient_steps=1,
            target_update_interval=50,
            exploration_fraction=0.7,
            verbose=1,
            tensorboard_log='highway_dqn/')

model.learn(int(2e4))
model.save('models/dqn_model')
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to highway_dqn/DQN_9
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.25     |
# |    ep_rew_mean      | 1.36     |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1        |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 9        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.75     |
# |    ep_rew_mean      | 1.72     |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 2        |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 22       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.83     |
# |    ep_rew_mean      | 1.77     |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 2        |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 34       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.69     |
# |    ep_rew_mean      | 1.67     |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 2        |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 43       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.75     |
# |    ep_rew_mean      | 1.73     |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 2        |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 55       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.5      |
# |    ep_rew_mean      | 2.9      |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 2        |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 108      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.57     |
# |    ep_rew_mean      | 3.63     |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 2        |
# |    time_elapsed     | 73       |
# |    total_timesteps  | 156      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.28     |
# |    ep_rew_mean      | 3.44     |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 2        |
# |    time_elapsed     | 79       |
# |    total_timesteps  | 169      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.42     |
# |    ep_rew_mean      | 3.53     |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 2        |
# |    time_elapsed     | 92       |
# |    total_timesteps  | 195      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.35     |
# |    ep_rew_mean      | 3.48     |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 2        |
# |    time_elapsed     | 101      |
# |    total_timesteps  | 214      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0208   |
# |    n_updates        | 13       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.23     |
# |    ep_rew_mean      | 3.4      |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 2        |
# |    time_elapsed     | 109      |
# |    total_timesteps  | 230      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0108   |
# |    n_updates        | 29       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.1      |
# |    ep_rew_mean      | 3.32     |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 2        |
# |    time_elapsed     | 116      |
# |    total_timesteps  | 245      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00611  |
# |    n_updates        | 44       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5        |
# |    ep_rew_mean      | 3.25     |
# |    exploration_rate | 0.982    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 2        |
# |    time_elapsed     | 123      |
# |    total_timesteps  | 260      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0732   |
# |    n_updates        | 59       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.07     |
# |    ep_rew_mean      | 3.3      |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 2        |
# |    time_elapsed     | 135      |
# |    total_timesteps  | 284      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0635   |
# |    n_updates        | 83       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.67     |
# |    ep_rew_mean      | 3.7      |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 2        |
# |    time_elapsed     | 163      |
# |    total_timesteps  | 340      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0598   |
# |    n_updates        | 139      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.78     |
# |    ep_rew_mean      | 3.78     |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 2        |
# |    time_elapsed     | 177      |
# |    total_timesteps  | 370      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.137    |
# |    n_updates        | 169      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.94     |
# |    ep_rew_mean      | 4.55     |
# |    exploration_rate | 0.968    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 2        |
# |    time_elapsed     | 226      |
# |    total_timesteps  | 472      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.14     |
# |    n_updates        | 271      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.76     |
# |    ep_rew_mean      | 4.43     |
# |    exploration_rate | 0.967    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 2        |
# |    time_elapsed     | 234      |
# |    total_timesteps  | 487      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0896   |
# |    n_updates        | 286      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.68     |
# |    ep_rew_mean      | 4.38     |
# |    exploration_rate | 0.966    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 2        |
# |    time_elapsed     | 245      |
# |    total_timesteps  | 508      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.124    |
# |    n_updates        | 307      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.53     |
# |    ep_rew_mean      | 4.27     |
# |    exploration_rate | 0.965    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 2        |
# |    time_elapsed     | 251      |
# |    total_timesteps  | 522      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.052    |
# |    n_updates        | 321      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.79     |
# |    ep_rew_mean      | 4.45     |
# |    exploration_rate | 0.961    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 2        |
# |    time_elapsed     | 274      |
# |    total_timesteps  | 570      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.17     |
# |    n_updates        | 369      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.14     |
# |    ep_rew_mean      | 4.68     |
# |    exploration_rate | 0.957    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 2        |
# |    time_elapsed     | 303      |
# |    total_timesteps  | 628      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.325    |
# |    n_updates        | 427      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.07     |
# |    ep_rew_mean      | 4.64     |
# |    exploration_rate | 0.956    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 2        |
# |    time_elapsed     | 314      |
# |    total_timesteps  | 650      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.129    |
# |    n_updates        | 449      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.28     |
# |    ep_rew_mean      | 4.78     |
# |    exploration_rate | 0.953    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 2        |
# |    time_elapsed     | 335      |
# |    total_timesteps  | 699      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.337    |
# |    n_updates        | 498      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.14     |
# |    ep_rew_mean      | 4.69     |
# |    exploration_rate | 0.952    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 2        |
# |    time_elapsed     | 342      |
# |    total_timesteps  | 714      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.193    |
# |    n_updates        | 513      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.64     |
# |    ep_rew_mean      | 5.02     |
# |    exploration_rate | 0.948    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 2        |
# |    time_elapsed     | 367      |
# |    total_timesteps  | 773      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.282    |
# |    n_updates        | 572      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19     |
# |    ep_rew_mean      | 5.39     |
# |    exploration_rate | 0.943    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 2        |
# |    time_elapsed     | 396      |
# |    total_timesteps  | 841      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.333    |
# |    n_updates        | 640      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.27     |
# |    ep_rew_mean      | 5.45     |
# |    exploration_rate | 0.942    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 2        |
# |    time_elapsed     | 404      |
# |    total_timesteps  | 861      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.079    |
# |    n_updates        | 660      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.35     |
# |    ep_rew_mean      | 5.5      |
# |    exploration_rate | 0.94     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 2        |
# |    time_elapsed     | 412      |
# |    total_timesteps  | 878      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.188    |
# |    n_updates        | 677      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.37     |
# |    ep_rew_mean      | 5.51     |
# |    exploration_rate | 0.939    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 2        |
# |    time_elapsed     | 419      |
# |    total_timesteps  | 892      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.265    |
# |    n_updates        | 691      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.33     |
# |    ep_rew_mean      | 5.48     |
# |    exploration_rate | 0.936    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 2        |
# |    time_elapsed     | 441      |
# |    total_timesteps  | 941      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.212    |
# |    n_updates        | 740      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.04     |
# |    ep_rew_mean      | 5.29     |
# |    exploration_rate | 0.935    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 2        |
# |    time_elapsed     | 449      |
# |    total_timesteps  | 960      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.208    |
# |    n_updates        | 759      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.05     |
# |    ep_rew_mean      | 5.29     |
# |    exploration_rate | 0.934    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 2        |
# |    time_elapsed     | 455      |
# |    total_timesteps  | 974      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0763   |
# |    n_updates        | 773      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.39     |
# |    ep_rew_mean      | 5.52     |
# |    exploration_rate | 0.93     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 2        |
# |    time_elapsed     | 480      |
# |    total_timesteps  | 1034     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.358    |
# |    n_updates        | 833      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.67     |
# |    ep_rew_mean      | 5.71     |
# |    exploration_rate | 0.927    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 2        |
# |    time_elapsed     | 501      |
# |    total_timesteps  | 1081     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.133    |
# |    n_updates        | 880      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.65     |
# |    ep_rew_mean      | 5.69     |
# |    exploration_rate | 0.926    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 2        |
# |    time_elapsed     | 507      |
# |    total_timesteps  | 1095     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.253    |
# |    n_updates        | 894      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.37     |
# |    ep_rew_mean      | 6.17     |
# |    exploration_rate | 0.92     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 2        |
# |    time_elapsed     | 543      |
# |    total_timesteps  | 1182     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.156    |
# |    n_updates        | 981      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.42     |
# |    ep_rew_mean      | 6.21     |
# |    exploration_rate | 0.918    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 2        |
# |    time_elapsed     | 552      |
# |    total_timesteps  | 1202     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.17     |
# |    n_updates        | 1001     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.32     |
# |    ep_rew_mean      | 6.14     |
# |    exploration_rate | 0.917    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 2        |
# |    time_elapsed     | 558      |
# |    total_timesteps  | 1216     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.156    |
# |    n_updates        | 1015     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.23     |
# |    ep_rew_mean      | 6.08     |
# |    exploration_rate | 0.914    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 2        |
# |    time_elapsed     | 579      |
# |    total_timesteps  | 1263     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.513    |
# |    n_updates        | 1062     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.39     |
# |    ep_rew_mean      | 6.19     |
# |    exploration_rate | 0.911    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 2        |
# |    time_elapsed     | 601      |
# |    total_timesteps  | 1309     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.334    |
# |    n_updates        | 1108     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.6      |
# |    ep_rew_mean      | 5.66     |
# |    exploration_rate | 0.91     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 2        |
# |    time_elapsed     | 612      |
# |    total_timesteps  | 1332     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.145    |
# |    n_updates        | 1131     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.58     |
# |    ep_rew_mean      | 5.65     |
# |    exploration_rate | 0.909    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 2        |
# |    time_elapsed     | 618      |
# |    total_timesteps  | 1345     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.124    |
# |    n_updates        | 1144     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.69     |
# |    ep_rew_mean      | 6.39     |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 2        |
# |    time_elapsed     | 680      |
# |    total_timesteps  | 1477     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.167    |
# |    n_updates        | 1276     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10       |
# |    ep_rew_mean      | 6.61     |
# |    exploration_rate | 0.897    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 2        |
# |    time_elapsed     | 702      |
# |    total_timesteps  | 1523     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.271    |
# |    n_updates        | 1322     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 6.67     |
# |    exploration_rate | 0.893    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 2        |
# |    time_elapsed     | 730      |
# |    total_timesteps  | 1580     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.145    |
# |    n_updates        | 1379     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.7      |
# |    ep_rew_mean      | 6.4      |
# |    exploration_rate | 0.892    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 2        |
# |    time_elapsed     | 738      |
# |    total_timesteps  | 1598     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.25     |
# |    n_updates        | 1397     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.59     |
# |    ep_rew_mean      | 6.33     |
# |    exploration_rate | 0.891    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 2        |
# |    time_elapsed     | 743      |
# |    total_timesteps  | 1609     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.15     |
# |    n_updates        | 1408     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.62     |
# |    ep_rew_mean      | 6.35     |
# |    exploration_rate | 0.887    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 2        |
# |    time_elapsed     | 768      |
# |    total_timesteps  | 1661     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.11     |
# |    n_updates        | 1460     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.68     |
# |    ep_rew_mean      | 6.39     |
# |    exploration_rate | 0.886    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 2        |
# |    time_elapsed     | 778      |
# |    total_timesteps  | 1682     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.126    |
# |    n_updates        | 1481     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.62     |
# |    ep_rew_mean      | 6.35     |
# |    exploration_rate | 0.882    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 2        |
# |    time_elapsed     | 803      |
# |    total_timesteps  | 1735     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.116    |
# |    n_updates        | 1534     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.43     |
# |    ep_rew_mean      | 6.22     |
# |    exploration_rate | 0.879    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 2        |
# |    time_elapsed     | 826      |
# |    total_timesteps  | 1784     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.331    |
# |    n_updates        | 1583     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.47     |
# |    ep_rew_mean      | 6.25     |
# |    exploration_rate | 0.877    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 2        |
# |    time_elapsed     | 838      |
# |    total_timesteps  | 1808     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.27     |
# |    n_updates        | 1607     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.43     |
# |    ep_rew_mean      | 6.22     |
# |    exploration_rate | 0.876    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 2        |
# |    time_elapsed     | 844      |
# |    total_timesteps  | 1821     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.189    |
# |    n_updates        | 1620     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.78     |
# |    ep_rew_mean      | 6.46     |
# |    exploration_rate | 0.873    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 2        |
# |    time_elapsed     | 868      |
# |    total_timesteps  | 1870     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.232    |
# |    n_updates        | 1669     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.46     |
# |    ep_rew_mean      | 6.25     |
# |    exploration_rate | 0.872    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 2        |
# |    time_elapsed     | 876      |
# |    total_timesteps  | 1887     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.149    |
# |    n_updates        | 1686     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.8      |
# |    ep_rew_mean      | 6.48     |
# |    exploration_rate | 0.868    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 2        |
# |    time_elapsed     | 901      |
# |    total_timesteps  | 1940     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.245    |
# |    n_updates        | 1739     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.77     |
# |    ep_rew_mean      | 6.46     |
# |    exploration_rate | 0.868    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 2        |
# |    time_elapsed     | 906      |
# |    total_timesteps  | 1951     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.261    |
# |    n_updates        | 1750     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.39     |
# |    ep_rew_mean      | 6.2      |
# |    exploration_rate | 0.866    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 2        |
# |    time_elapsed     | 917      |
# |    total_timesteps  | 1973     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.3      |
# |    n_updates        | 1772     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.81     |
# |    ep_rew_mean      | 6.49     |
# |    exploration_rate | 0.86     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 2        |
# |    time_elapsed     | 959      |
# |    total_timesteps  | 2062     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.128    |
# |    n_updates        | 1861     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.2     |
# |    ep_rew_mean      | 6.75     |
# |    exploration_rate | 0.857    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 2        |
# |    time_elapsed     | 983      |
# |    total_timesteps  | 2114     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.376    |
# |    n_updates        | 1913     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.65     |
# |    ep_rew_mean      | 6.39     |
# |    exploration_rate | 0.854    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 2        |
# |    time_elapsed     | 999      |
# |    total_timesteps  | 2147     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.117    |
# |    n_updates        | 1946     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.97     |
# |    ep_rew_mean      | 6.6      |
# |    exploration_rate | 0.851    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 2        |
# |    time_elapsed     | 1024     |
# |    total_timesteps  | 2199     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.174    |
# |    n_updates        | 1998     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.2     |
# |    ep_rew_mean      | 6.77     |
# |    exploration_rate | 0.848    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 2        |
# |    time_elapsed     | 1043     |
# |    total_timesteps  | 2239     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.226    |
# |    n_updates        | 2038     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 6.97     |
# |    exploration_rate | 0.843    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 2        |
# |    time_elapsed     | 1080     |
# |    total_timesteps  | 2315     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.118    |
# |    n_updates        | 2114     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 6.83     |
# |    exploration_rate | 0.841    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 2        |
# |    time_elapsed     | 1092     |
# |    total_timesteps  | 2340     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.156    |
# |    n_updates        | 2139     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 7.04     |
# |    exploration_rate | 0.837    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 2        |
# |    time_elapsed     | 1117     |
# |    total_timesteps  | 2395     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.227    |
# |    n_updates        | 2194     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 7.32     |
# |    exploration_rate | 0.834    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 2        |
# |    time_elapsed     | 1143     |
# |    total_timesteps  | 2449     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.104    |
# |    n_updates        | 2248     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 6.79     |
# |    exploration_rate | 0.83     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 2        |
# |    time_elapsed     | 1168     |
# |    total_timesteps  | 2503     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0802   |
# |    n_updates        | 2302     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.92     |
# |    ep_rew_mean      | 6.56     |
# |    exploration_rate | 0.829    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 2        |
# |    time_elapsed     | 1174     |
# |    total_timesteps  | 2515     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.192    |
# |    n_updates        | 2314     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.97     |
# |    ep_rew_mean      | 6.59     |
# |    exploration_rate | 0.825    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 2        |
# |    time_elapsed     | 1203     |
# |    total_timesteps  | 2577     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0984   |
# |    n_updates        | 2376     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 6.86     |
# |    exploration_rate | 0.821    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 2        |
# |    time_elapsed     | 1230     |
# |    total_timesteps  | 2634     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.044    |
# |    n_updates        | 2433     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 7.25     |
# |    exploration_rate | 0.816    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 2        |
# |    time_elapsed     | 1264     |
# |    total_timesteps  | 2705     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.143    |
# |    n_updates        | 2504     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 7.24     |
# |    exploration_rate | 0.813    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 2        |
# |    time_elapsed     | 1288     |
# |    total_timesteps  | 2755     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0933   |
# |    n_updates        | 2554     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 7.23     |
# |    exploration_rate | 0.812    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 2        |
# |    time_elapsed     | 1297     |
# |    total_timesteps  | 2775     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.173    |
# |    n_updates        | 2574     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 7.21     |
# |    exploration_rate | 0.808    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 2        |
# |    time_elapsed     | 1322     |
# |    total_timesteps  | 2826     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.294    |
# |    n_updates        | 2625     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 7.23     |
# |    exploration_rate | 0.805    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 2        |
# |    time_elapsed     | 1346     |
# |    total_timesteps  | 2878     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.205    |
# |    n_updates        | 2677     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.5     |
# |    ep_rew_mean      | 7.6      |
# |    exploration_rate | 0.799    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 2        |
# |    time_elapsed     | 1383     |
# |    total_timesteps  | 2957     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0841   |
# |    n_updates        | 2756     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.9     |
# |    ep_rew_mean      | 7.9      |
# |    exploration_rate | 0.795    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 2        |
# |    time_elapsed     | 1410     |
# |    total_timesteps  | 3014     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0692   |
# |    n_updates        | 2813     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.3     |
# |    ep_rew_mean      | 8.15     |
# |    exploration_rate | 0.79     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 2        |
# |    time_elapsed     | 1452     |
# |    total_timesteps  | 3101     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0397   |
# |    n_updates        | 2900     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.3     |
# |    ep_rew_mean      | 8.16     |
# |    exploration_rate | 0.788    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 2        |
# |    time_elapsed     | 1461     |
# |    total_timesteps  | 3120     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.208    |
# |    n_updates        | 2919     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.4     |
# |    ep_rew_mean      | 8.24     |
# |    exploration_rate | 0.784    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 2        |
# |    time_elapsed     | 1491     |
# |    total_timesteps  | 3185     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.156    |
# |    n_updates        | 2984     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 8.53     |
# |    exploration_rate | 0.78     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 2        |
# |    time_elapsed     | 1517     |
# |    total_timesteps  | 3239     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0744   |
# |    n_updates        | 3038     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.8     |
# |    ep_rew_mean      | 8.48     |
# |    exploration_rate | 0.779    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 2        |
# |    time_elapsed     | 1524     |
# |    total_timesteps  | 3254     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.162    |
# |    n_updates        | 3053     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.2     |
# |    ep_rew_mean      | 8.08     |
# |    exploration_rate | 0.777    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 2        |
# |    time_elapsed     | 1538     |
# |    total_timesteps  | 3283     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.297    |
# |    n_updates        | 3082     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.2     |
# |    ep_rew_mean      | 8.07     |
# |    exploration_rate | 0.774    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 2        |
# |    time_elapsed     | 1562     |
# |    total_timesteps  | 3334     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.222    |
# |    n_updates        | 3133     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12       |
# |    ep_rew_mean      | 7.95     |
# |    exploration_rate | 0.773    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 2        |
# |    time_elapsed     | 1570     |
# |    total_timesteps  | 3350     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.201    |
# |    n_updates        | 3149     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.6     |
# |    ep_rew_mean      | 7.67     |
# |    exploration_rate | 0.772    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 2        |
# |    time_elapsed     | 1575     |
# |    total_timesteps  | 3361     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.242    |
# |    n_updates        | 3160     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.8     |
# |    ep_rew_mean      | 7.77     |
# |    exploration_rate | 0.768    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 2        |
# |    time_elapsed     | 1602     |
# |    total_timesteps  | 3416     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.308    |
# |    n_updates        | 3215     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 7.4      |
# |    exploration_rate | 0.767    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 2        |
# |    time_elapsed     | 1611     |
# |    total_timesteps  | 3436     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.399    |
# |    n_updates        | 3235     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.5     |
# |    ep_rew_mean      | 7.59     |
# |    exploration_rate | 0.763    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 2        |
# |    time_elapsed     | 1637     |
# |    total_timesteps  | 3490     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0762   |
# |    n_updates        | 3289     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | 7.48     |
# |    exploration_rate | 0.761    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 2        |
# |    time_elapsed     | 1655     |
# |    total_timesteps  | 3528     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.245    |
# |    n_updates        | 3327     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 7.28     |
# |    exploration_rate | 0.759    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 2        |
# |    time_elapsed     | 1666     |
# |    total_timesteps  | 3553     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.191    |
# |    n_updates        | 3352     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 7.51     |
# |    exploration_rate | 0.753    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 2        |
# ...
# |    time_elapsed     | 7453     |
# |    total_timesteps  | 15799    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0143   |
# |    n_updates        | 15598    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.2     |
# |    ep_rew_mean      | 22.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 892      |
# |    fps              | 2        |
# |    time_elapsed     | 7530     |
# |    total_timesteps  | 15959    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.052    |
# |    n_updates        | 15758    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.4     |
# |    ep_rew_mean      | 22.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 896      |
# |    fps              | 2        |
# |    time_elapsed     | 7570     |
# |    total_timesteps  | 16044    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0545   |
# |    n_updates        | 15843    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.8     |
# |    ep_rew_mean      | 22.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 900      |
# |    fps              | 2        |
# |    time_elapsed     | 7634     |
# |    total_timesteps  | 16180    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.137    |
# |    n_updates        | 15979    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.4     |
# |    ep_rew_mean      | 22.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 904      |
# |    fps              | 2        |
# |    time_elapsed     | 7692     |
# |    total_timesteps  | 16302    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0682   |
# |    n_updates        | 16101    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.4     |
# |    ep_rew_mean      | 22.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 908      |
# |    fps              | 2        |
# |    time_elapsed     | 7767     |
# |    total_timesteps  | 16462    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0406   |
# |    n_updates        | 16261    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.8     |
# |    ep_rew_mean      | 22.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 912      |
# |    fps              | 2        |
# |    time_elapsed     | 7843     |
# |    total_timesteps  | 16622    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0399   |
# |    n_updates        | 16421    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.8     |
# |    ep_rew_mean      | 22.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 916      |
# |    fps              | 2        |
# |    time_elapsed     | 7919     |
# |    total_timesteps  | 16782    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0503   |
# |    n_updates        | 16581    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.1     |
# |    ep_rew_mean      | 22.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 920      |
# |    fps              | 2        |
# |    time_elapsed     | 7994     |
# |    total_timesteps  | 16942    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00228  |
# |    n_updates        | 16741    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.8     |
# |    ep_rew_mean      | 22.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 924      |
# |    fps              | 2        |
# |    time_elapsed     | 8054     |
# |    total_timesteps  | 17067    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00359  |
# |    n_updates        | 16866    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.2     |
# |    ep_rew_mean      | 23       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 928      |
# |    fps              | 2        |
# |    time_elapsed     | 8129     |
# |    total_timesteps  | 17227    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00167  |
# |    n_updates        | 17026    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.5     |
# |    ep_rew_mean      | 23.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 932      |
# |    fps              | 2        |
# |    time_elapsed     | 8185     |
# |    total_timesteps  | 17348    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0148   |
# |    n_updates        | 17147    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.5     |
# |    ep_rew_mean      | 23.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 936      |
# |    fps              | 2        |
# |    time_elapsed     | 8260     |
# |    total_timesteps  | 17508    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00283  |
# |    n_updates        | 17307    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.5     |
# |    ep_rew_mean      | 23.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 940      |
# |    fps              | 2        |
# |    time_elapsed     | 8336     |
# |    total_timesteps  | 17668    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00372  |
# |    n_updates        | 17467    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.5     |
# |    ep_rew_mean      | 23.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 944      |
# |    fps              | 2        |
# |    time_elapsed     | 8411     |
# |    total_timesteps  | 17828    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0158   |
# |    n_updates        | 17627    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.5     |
# |    ep_rew_mean      | 23.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 948      |
# |    fps              | 2        |
# |    time_elapsed     | 8486     |
# |    total_timesteps  | 17988    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00308  |
# |    n_updates        | 17787    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.9     |
# |    ep_rew_mean      | 23.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 952      |
# |    fps              | 2        |
# |    time_elapsed     | 8561     |
# |    total_timesteps  | 18148    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.128    |
# |    n_updates        | 17947    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.9     |
# |    ep_rew_mean      | 23.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 956      |
# |    fps              | 2        |
# |    time_elapsed     | 8620     |
# |    total_timesteps  | 18273    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.141    |
# |    n_updates        | 18072    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.5     |
# |    ep_rew_mean      | 23.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 960      |
# |    fps              | 2        |
# |    time_elapsed     | 8682     |
# |    total_timesteps  | 18405    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.153    |
# |    n_updates        | 18204    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35       |
# |    ep_rew_mean      | 23.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 964      |
# |    fps              | 2        |
# |    time_elapsed     | 8734     |
# |    total_timesteps  | 18515    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00284  |
# |    n_updates        | 18314    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35       |
# |    ep_rew_mean      | 23.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 968      |
# |    fps              | 2        |
# |    time_elapsed     | 8808     |
# |    total_timesteps  | 18675    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00228  |
# |    n_updates        | 18474    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.7     |
# |    ep_rew_mean      | 23.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 972      |
# |    fps              | 2        |
# |    time_elapsed     | 8853     |
# |    total_timesteps  | 18768    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0389   |
# |    n_updates        | 18567    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.4     |
# |    ep_rew_mean      | 23.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 976      |
# |    fps              | 2        |
# |    time_elapsed     | 8913     |
# |    total_timesteps  | 18897    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0674   |
# |    n_updates        | 18696    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.7     |
# |    ep_rew_mean      | 23.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 980      |
# |    fps              | 2        |
# |    time_elapsed     | 8974     |
# |    total_timesteps  | 19021    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0734   |
# |    n_updates        | 18820    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35       |
# |    ep_rew_mean      | 23.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 984      |
# |    fps              | 2        |
# |    time_elapsed     | 9052     |
# |    total_timesteps  | 19181    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00166  |
# |    n_updates        | 18980    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.1     |
# |    ep_rew_mean      | 23.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 988      |
# |    fps              | 2        |
# |    time_elapsed     | 9112     |
# |    total_timesteps  | 19307    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00172  |
# |    n_updates        | 19106    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.7     |
# |    ep_rew_mean      | 23.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 992      |
# |    fps              | 2        |
# |    time_elapsed     | 9171     |
# |    total_timesteps  | 19433    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00627  |
# |    n_updates        | 19232    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.5     |
# |    ep_rew_mean      | 23.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 996      |
# |    fps              | 2        |
# |    time_elapsed     | 9246     |
# |    total_timesteps  | 19593    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.129    |
# |    n_updates        | 19392    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35       |
# |    ep_rew_mean      | 23.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1000     |
# |    fps              | 2        |
# |    time_elapsed     | 9287     |
# |    total_timesteps  | 19679    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00914  |
# |    n_updates        | 19478    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35       |
# |    ep_rew_mean      | 23.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1004     |
# |    fps              | 2        |
# |    time_elapsed     | 9345     |
# |    total_timesteps  | 19801    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0771   |
# |    n_updates        | 19600    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35       |
# |    ep_rew_mean      | 23.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1008     |
# |    fps              | 2        |
# |    time_elapsed     | 9421     |
# |    total_timesteps  | 19961    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.019    |
# |    n_updates        | 19760    |
# ----------------------------------

# %% [markdown]
# Visulise

# %%
import base64
from pathlib import Path

from gymnasium.wrappers import RecordVideo
from IPython import display as ipythondisplay
from pyvirtualdisplay import Display



def record_videos(env, video_folder="videos"):
    wrapped = RecordVideo(
        env, video_folder=video_folder, episode_trigger=lambda e: True
    )

    # Capture intermediate frames
    env.unwrapped.set_record_video_wrapper(wrapped)

    return wrapped


def show_videos(path="videos"):
    html = []
    for mp4 in Path(path).glob("*.mp4"):
        video_b64 = base64.b64encode(mp4.read_bytes())
        html.append(
            """<video alt="{}" autoplay
                      loop controls style="height: 400px;">
                      <source src="data:video/mp4;base64,{}" type="video/mp4" />
                 </video>""".format(
                mp4, video_b64.decode("ascii")
            )
        )
    ipythondisplay.display(ipythondisplay.HTML(data="<br>".join(html)))

# %%
from gymnasium.wrappers import RecordVideo
# base setting
vehicleCount = 10

# environment setting
config = {

    "observation": {
        "type": "Kinematics",
        "features": ["presence", "x", "y", "vx", "vy"],
        "absolute": True,
        "normalize": True,
        "vehicles_count": vehicleCount,
        "see_behind": True,
    },
    "action": {
        "type": "DiscreteMetaAction",
        "target_speeds": np.linspace(0, 32, 9),
    },
    "duration": 40,
    "vehicles_density": 2,
    "show_trajectories": True,
    "render_agent": True,
}

modelDqnllm = DQN.load("models/dqn_model")

env = gym.make('highway-v0', render_mode='rgb_array')
env.configure(config)
env = record_videos(env)
for episode in trange(3, desc='Test episodes'):
    (obs, info), done, truncated = env.reset(), False, False
    while not (done or truncated):
        action, _ = modelDqnllm.predict(obs, deterministic=True)
        obs, reward, done, truncated, info = env.step(int(action))
env.close()
show_videos()
# Out:
# /home/prachit/.local/lib/python3.8/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.configure to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.configure` for environment variables or `env.get_wrapper_attr('configure')` that will search the reminding wrappers.
#   logger.warn(
# /home/prachit/.local/lib/python3.8/site-packages/gymnasium/wrappers/record_video.py:94: UserWarning: WARN: Overwriting existing videos at /home/prachit/Desktop/Reward-shaping-with-LLMS/videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Test episodes:   0%|          | 0/3 [00:13<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 35
#      33     while not (done or truncated):
#      34         action, _ = modelDqnllm.predict(obs, deterministic=True)
# ---> 35         obs, reward, done, truncated, info = env.step(int(action))
#      36 env.close()
#      37 show_videos()
#
# File ~/.local/lib/python3.8/site-packages/gymnasium/wrappers/record_video.py:166, in RecordVideo.step(self, action)
#     158 def step(self, action):
#     159     """Steps through the environment using action, recording observations if :attr:`self.recording`."""
#     160     (
#     161         observations,
#     162         rewards,
#     163         terminateds,
#     164         truncateds,
#     165         infos,
# --> 166     ) = self.env.step(action)
#     168     if not (self.terminated or self.truncated):
#     169         # increment steps and episodes
#     170         self.step_id += 1
#
# File ~/.local/lib/python3.8/site-packages/gymnasium/wrappers/order_enforcing.py:56, in OrderEnforcing.step(self, action)
#      54 if not self._has_reset:
#      55     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 56 return self.env.step(action)
#
# File ~/.local/lib/python3.8/site-packages/gymnasium/wrappers/env_checker.py:51, in PassiveEnvChecker.step(self, action)
#      49     return env_step_passive_checker(self.env, action)
#      50 else:
# ---> 51     return self.env.step(action)
#
# File ~/.local/lib/python3.8/site-packages/highway_env/envs/common/abstract.py:240, in AbstractEnv.step(self, action)
#     235     raise NotImplementedError(
#     236         "The road and vehicle must be initialized in the environment implementation"
#     237     )
#     239 self.time += 1 / self.config["policy_frequency"]
# --> 240 self._simulate(action)
#     242 obs = self.observation_type.observe()
#     243 reward = self._reward(action)
#
# File ~/.local/lib/python3.8/site-packages/highway_env/envs/common/abstract.py:280, in AbstractEnv._simulate(self, action)
#     275     # Automatically render intermediate simulation steps if a viewer has been launched
#     276     # Ignored if the rendering is done offscreen
#     277     if (
#     278         frame < frames - 1
#     279     ):  # Last frame will be rendered through env.render() as usual
# --> 280         self._automatic_rendering()
#     282 self.enable_auto_render = False
#
# File ~/.local/lib/python3.8/site-packages/highway_env/envs/common/abstract.py:338, in AbstractEnv._automatic_rendering(self)
#     336 if self.viewer is not None and self.enable_auto_render:
#     337     if self._record_video_wrapper and self._record_video_wrapper.video_recorder:
# --> 338         self._record_video_wrapper.video_recorder.capture_frame()
#     339     else:
#     340         self.render()
#
# File ~/.local/lib/python3.8/site-packages/gymnasium/wrappers/monitoring/video_recorder.py:113, in VideoRecorder.capture_frame(self)
#     111 def capture_frame(self):
#     112     """Render the given `env` and add the resulting frame to the video."""
# --> 113     frame = self.env.render()
#     114     if isinstance(frame, List):
#     115         self.render_history += frame
#
# File ~/.local/lib/python3.8/site-packages/gymnasium/wrappers/order_enforcing.py:70, in OrderEnforcing.render(self, *args, **kwargs)
#      65 if not self._disable_render_order_enforcing and not self._has_reset:
#      66     raise ResetNeeded(
#      67         "Cannot call `env.render()` before calling `env.reset()`, if this is a intended action, "
#      68         "set `disable_render_order_enforcing=True` on the OrderEnforcer wrapper."
#      69     )
# ---> 70 return self.env.render(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/gymnasium/wrappers/env_checker.py:67, in PassiveEnvChecker.render(self, *args, **kwargs)
#      65     return env_render_passive_checker(self.env, *args, **kwargs)
#      66 else:
# ---> 67     return self.env.render(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/highway_env/envs/common/abstract.py:303, in AbstractEnv.render(self)
#     299     self.viewer = EnvViewer(self)
#     301 self.enable_auto_render = True
# --> 303 self.viewer.display()
#     305 if not self.viewer.offscreen:
#     306     self.viewer.handle_events()
#
# File ~/.local/lib/python3.8/site-packages/highway_env/envs/common/graphics.py:124, in EnvViewer.display(self)
#     121     return
#     123 self.sim_surface.move_display_window_to(self.window_position())
# --> 124 RoadGraphics.display(self.env.road, self.sim_surface)
#     126 if self.vehicle_trajectory:
#     127     VehicleGraphics.display_trajectory(
#     128         self.vehicle_trajectory, self.sim_surface, offscreen=self.offscreen
#     129     )
#
# File ~/.local/lib/python3.8/site-packages/highway_env/road/graphics.py:307, in RoadGraphics.display(road, surface)
#     305 for _to in road.network.graph[_from].keys():
#     306     for l in road.network.graph[_from][_to]:
# --> 307         LaneGraphics.display(l, surface)
#
# File ~/.local/lib/python3.8/site-packages/highway_env/road/graphics.py:145, in LaneGraphics.display(cls, lane, surface)
#     143 for side in range(2):
#     144     if lane.line_types[side] == LineType.STRIPED:
# --> 145         cls.striped_line(lane, surface, stripes_count, s0, side)
#     146     elif lane.line_types[side] == LineType.CONTINUOUS:
#     147         cls.continuous_curve(lane, surface, stripes_count, s0, side)
#
# File ~/.local/lib/python3.8/site-packages/highway_env/road/graphics.py:176, in LaneGraphics.striped_line(cls, lane, surface, stripes_count, longitudinal, side)
#     170 ends = (
#     171     longitudinal
#     172     + np.arange(stripes_count) * cls.STRIPE_SPACING
#     173     + cls.STRIPE_LENGTH
#     174 )
#     175 lats = [(side - 0.5) * lane.width_at(s) for s in starts]
# --> 176 cls.draw_stripes(lane, surface, starts, ends, lats)
#
# File ~/.local/lib/python3.8/site-packages/highway_env/road/graphics.py:253, in LaneGraphics.draw_stripes(cls, lane, surface, starts, ends, lats)
#     248 for k, _ in enumerate(starts):
#     249     if abs(starts[k] - ends[k]) > 0.5 * cls.STRIPE_LENGTH:
#     250         pygame.draw.line(
#     251             surface,
#     252             surface.WHITE,
# --> 253             (surface.vec2pix(lane.position(starts[k], lats[k]))),
#     254             (surface.vec2pix(lane.position(ends[k], lats[k]))),
#     255             max(surface.pix(cls.STRIPE_WIDTH), 1),
#     256         )
#
# File ~/.local/lib/python3.8/site-packages/highway_env/road/lane.py:200, in StraightLane.position(self, longitudinal, lateral)
#     196 def position(self, longitudinal: float, lateral: float) -> np.ndarray:
#     197     return (
#     198         self.start
#     199         + longitudinal * self.direction
# --> 200         + lateral * self.direction_lateral
#     201     )
#
# KeyboardInterrupt:
