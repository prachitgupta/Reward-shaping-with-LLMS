# %% [markdown]
# # Highway with SB3's DQN
#
# ##  Warming up
# We start with a few useful installs and imports:

# %%
# # Install environment and agent
# !pip install highway-env
# # TODO: we use the bleeding edge version because the current stable version does not support the latest gym>=0.21 versions. Revert back to stable at the next SB3 release.
# !pip install git+https://github.com/DLR-RM/stable-baselines3

# # Environment
import gymnasium as gym
import highway_env

gym.register_envs(highway_env)

# Agent
from stable_baselines3 import DQN


import sys
from tqdm.notebook import trange
# !pip install tensorboardx gym pyvirtualdisplay
# !apt-get install -y xvfb ffmpeg
# Out:
# 2024-09-25 19:00:40.651428: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-09-25 19:00:40.653908: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-09-25 19:00:40.692948: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-25 19:00:41.580905: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Training
# Run tensorboard locally to visualize training.

# %%
import base64
from pathlib import Path

from gymnasium.wrappers import RecordVideo
from IPython import display as ipythondisplay
from pyvirtualdisplay import Display



def record_videos(env, video_folder="videos"):
    wrapped = RecordVideo(
        env, video_folder=video_folder, episode_trigger=lambda e: True
    )

    # Capture intermediate frames
    env.unwrapped.set_record_video_wrapper(wrapped)

    return wrapped


def show_videos(path="videos"):
    html = []
    for mp4 in Path(path).glob("*.mp4"):
        video_b64 = base64.b64encode(mp4.read_bytes())
        html.append(
            """<video alt="{}" autoplay
                      loop controls style="height: 400px;">
                      <source src="data:video/mp4;base64,{}" type="video/mp4" />
                 </video>""".format(
                mp4, video_b64.decode("ascii")
            )
        )
    ipythondisplay.display(ipythondisplay.HTML(data="<br>".join(html)))

# %%
model = DQN('MlpPolicy', 'highway-fast-v0',
                policy_kwargs=dict(net_arch=[256, 256]),
                learning_rate=5e-4,
                buffer_size=15000,
                learning_starts=200,
                batch_size=32,
                gamma=0.8,
                train_freq=1,
                gradient_steps=1,
                target_update_interval=50,
                exploration_fraction=0.7,
                verbose=1,
                tensorboard_log='highway_dqn/')
model.learn(int(2e4))
model.save('models/dqn_model_default_fast')
# Out:
# Using cpu device
# Creating environment from the given name 'highway-fast-v0'
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to highway_dqn/DQN_7
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.5      |
# |    ep_rew_mean      | 6.89     |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 12       |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 38       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 9.74     |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 13       |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 109      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 13       |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 167      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.2     |
# |    ep_rew_mean      | 9.16     |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 13       |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 196      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | 8.39     |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 13       |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 226      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0353   |
# |    n_updates        | 25       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.7     |
# |    ep_rew_mean      | 8.75     |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 12       |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 281      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0647   |
# |    n_updates        | 80       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.9     |
# |    ep_rew_mean      | 8.87     |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 12       |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 333      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.128    |
# |    n_updates        | 132      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.4     |
# |    ep_rew_mean      | 9.28     |
# |    exploration_rate | 0.973    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 12       |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 398      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0137   |
# |    n_updates        | 197      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.1     |
# |    ep_rew_mean      | 9.08     |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 12       |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 435      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.155    |
# |    n_updates        | 234      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.9     |
# |    ep_rew_mean      | 8.97     |
# |    exploration_rate | 0.968    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 11       |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 478      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.188    |
# |    n_updates        | 277      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.9     |
# |    ep_rew_mean      | 8.91     |
# |    exploration_rate | 0.965    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 12       |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 523      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0987   |
# |    n_updates        | 322      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.5     |
# |    ep_rew_mean      | 8.62     |
# |    exploration_rate | 0.963    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 12       |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 552      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.477    |
# |    n_updates        | 351      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | 8.47     |
# |    exploration_rate | 0.96     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 12       |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 586      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.265    |
# |    n_updates        | 385      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 8.52     |
# |    exploration_rate | 0.957    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 11       |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 636      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.18     |
# |    n_updates        | 435      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.8     |
# |    ep_rew_mean      | 8.88     |
# |    exploration_rate | 0.952    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 11       |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 708      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.279    |
# |    n_updates        | 507      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.9     |
# |    ep_rew_mean      | 8.97     |
# |    exploration_rate | 0.948    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 11       |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 761      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.375    |
# |    n_updates        | 560      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.7     |
# |    ep_rew_mean      | 8.85     |
# |    exploration_rate | 0.946    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 11       |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 797      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.212    |
# |    n_updates        | 596      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.5     |
# |    ep_rew_mean      | 8.69     |
# |    exploration_rate | 0.944    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 11       |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 829      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.391    |
# |    n_updates        | 628      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 8.47     |
# |    exploration_rate | 0.942    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 11       |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 854      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.189    |
# |    n_updates        | 653      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 8.3      |
# |    exploration_rate | 0.94     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 11       |
# |    time_elapsed     | 74       |
# |    total_timesteps  | 883      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.286    |
# |    n_updates        | 682      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 8.02     |
# |    exploration_rate | 0.939    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 11       |
# |    time_elapsed     | 75       |
# |    total_timesteps  | 897      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.636    |
# |    n_updates        | 696      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 8.09     |
# |    exploration_rate | 0.936    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 11       |
# |    time_elapsed     | 79       |
# |    total_timesteps  | 944      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.298    |
# |    n_updates        | 743      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 8.21     |
# |    exploration_rate | 0.932    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 11       |
# |    time_elapsed     | 84       |
# |    total_timesteps  | 1003     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.351    |
# |    n_updates        | 802      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 8.25     |
# |    exploration_rate | 0.929    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 11       |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 1051     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.21     |
# |    n_updates        | 850      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 8.19     |
# |    exploration_rate | 0.926    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 11       |
# |    time_elapsed     | 90       |
# |    total_timesteps  | 1087     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.296    |
# |    n_updates        | 886      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 8.28     |
# |    exploration_rate | 0.923    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 11       |
# |    time_elapsed     | 94       |
# |    total_timesteps  | 1135     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.471    |
# |    n_updates        | 934      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 8.33     |
# |    exploration_rate | 0.918    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 12       |
# |    time_elapsed     | 99       |
# |    total_timesteps  | 1205     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.188    |
# |    n_updates        | 1004     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 8.08     |
# |    exploration_rate | 0.916    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 12       |
# |    time_elapsed     | 101      |
# |    total_timesteps  | 1233     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.3      |
# |    n_updates        | 1032     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.8     |
# |    ep_rew_mean      | 8.18     |
# |    exploration_rate | 0.913    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 12       |
# |    time_elapsed     | 104      |
# |    total_timesteps  | 1276     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.253    |
# |    n_updates        | 1075     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 8.41     |
# |    exploration_rate | 0.909    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 12       |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 1335     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.155    |
# |    n_updates        | 1134     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.8     |
# |    ep_rew_mean      | 8.23     |
# |    exploration_rate | 0.907    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 12       |
# |    time_elapsed     | 110      |
# |    total_timesteps  | 1366     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.529    |
# |    n_updates        | 1165     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 8.44     |
# |    exploration_rate | 0.902    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 12       |
# |    time_elapsed     | 115      |
# |    total_timesteps  | 1443     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.213    |
# |    n_updates        | 1242     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 8.16     |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 12       |
# |    time_elapsed     | 118      |
# |    total_timesteps  | 1472     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.284    |
# |    n_updates        | 1271     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 8.31     |
# |    exploration_rate | 0.896    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 12       |
# |    time_elapsed     | 122      |
# |    total_timesteps  | 1532     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.235    |
# |    n_updates        | 1331     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | 8.52     |
# |    exploration_rate | 0.891    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 12       |
# |    time_elapsed     | 127      |
# |    total_timesteps  | 1604     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0214   |
# |    n_updates        | 1403     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 8.64     |
# |    exploration_rate | 0.887    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 12       |
# |    time_elapsed     | 131      |
# |    total_timesteps  | 1664     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.272    |
# |    n_updates        | 1463     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.6     |
# |    ep_rew_mean      | 8.74     |
# |    exploration_rate | 0.884    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 12       |
# |    time_elapsed     | 134      |
# |    total_timesteps  | 1709     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.258    |
# |    n_updates        | 1508     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.7     |
# |    ep_rew_mean      | 8.84     |
# |    exploration_rate | 0.881    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 12       |
# |    time_elapsed     | 138      |
# |    total_timesteps  | 1759     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0118   |
# |    n_updates        | 1558     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.6     |
# |    ep_rew_mean      | 8.77     |
# |    exploration_rate | 0.878    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 12       |
# |    time_elapsed     | 140      |
# |    total_timesteps  | 1798     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.346    |
# |    n_updates        | 1597     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | 8.54     |
# |    exploration_rate | 0.875    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 12       |
# |    time_elapsed     | 144      |
# |    total_timesteps  | 1841     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.49     |
# |    n_updates        | 1640     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 8.43     |
# |    exploration_rate | 0.872    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 12       |
# |    time_elapsed     | 146      |
# |    total_timesteps  | 1883     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.28     |
# |    n_updates        | 1682     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 8.44     |
# |    exploration_rate | 0.87     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 12       |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 1919     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.283    |
# |    n_updates        | 1718     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 8.45     |
# |    exploration_rate | 0.867    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 12       |
# |    time_elapsed     | 151      |
# |    total_timesteps  | 1954     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.213    |
# |    n_updates        | 1753     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.8     |
# |    ep_rew_mean      | 8.87     |
# |    exploration_rate | 0.862    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 12       |
# |    time_elapsed     | 157      |
# |    total_timesteps  | 2029     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.66     |
# |    n_updates        | 1828     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.9     |
# |    ep_rew_mean      | 8.96     |
# |    exploration_rate | 0.86     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 12       |
# |    time_elapsed     | 159      |
# |    total_timesteps  | 2069     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.21     |
# |    n_updates        | 1868     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.3     |
# |    ep_rew_mean      | 9.27     |
# |    exploration_rate | 0.856    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 12       |
# |    time_elapsed     | 163      |
# |    total_timesteps  | 2123     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.113    |
# |    n_updates        | 1922     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.5     |
# |    ep_rew_mean      | 9.41     |
# |    exploration_rate | 0.851    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 13       |
# |    time_elapsed     | 168      |
# |    total_timesteps  | 2193     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.151    |
# |    n_updates        | 1992     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.3     |
# |    ep_rew_mean      | 9.25     |
# |    exploration_rate | 0.849    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 13       |
# |    time_elapsed     | 171      |
# |    total_timesteps  | 2230     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.191    |
# |    n_updates        | 2029     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.3     |
# |    ep_rew_mean      | 9.23     |
# |    exploration_rate | 0.845    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 13       |
# |    time_elapsed     | 174      |
# |    total_timesteps  | 2278     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.3      |
# |    n_updates        | 2077     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.1     |
# |    ep_rew_mean      | 9.12     |
# |    exploration_rate | 0.844    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 13       |
# |    time_elapsed     | 176      |
# |    total_timesteps  | 2301     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.167    |
# |    n_updates        | 2100     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.4     |
# |    ep_rew_mean      | 9.32     |
# |    exploration_rate | 0.839    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 13       |
# |    time_elapsed     | 182      |
# |    total_timesteps  | 2375     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.171    |
# |    n_updates        | 2174     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.1     |
# |    ep_rew_mean      | 9.02     |
# |    exploration_rate | 0.836    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 13       |
# |    time_elapsed     | 184      |
# |    total_timesteps  | 2410     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.39     |
# |    n_updates        | 2209     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.3     |
# |    ep_rew_mean      | 9.25     |
# |    exploration_rate | 0.833    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 13       |
# |    time_elapsed     | 188      |
# |    total_timesteps  | 2467     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0888   |
# |    n_updates        | 2266     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.2     |
# |    ep_rew_mean      | 9.15     |
# |    exploration_rate | 0.831    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 13       |
# |    time_elapsed     | 190      |
# |    total_timesteps  | 2496     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0343   |
# |    n_updates        | 2295     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.9     |
# |    ep_rew_mean      | 8.94     |
# |    exploration_rate | 0.828    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 13       |
# |    time_elapsed     | 193      |
# |    total_timesteps  | 2529     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.396    |
# |    n_updates        | 2328     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.1     |
# |    ep_rew_mean      | 9.06     |
# |    exploration_rate | 0.825    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 13       |
# |    time_elapsed     | 196      |
# |    total_timesteps  | 2578     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.203    |
# |    n_updates        | 2377     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.9     |
# |    ep_rew_mean      | 8.93     |
# |    exploration_rate | 0.821    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 13       |
# |    time_elapsed     | 201      |
# |    total_timesteps  | 2637     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.404    |
# |    n_updates        | 2436     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.9     |
# |    ep_rew_mean      | 8.89     |
# |    exploration_rate | 0.82     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 13       |
# |    time_elapsed     | 202      |
# |    total_timesteps  | 2660     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.518    |
# |    n_updates        | 2459     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 8.55     |
# |    exploration_rate | 0.818    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 13       |
# |    time_elapsed     | 204      |
# |    total_timesteps  | 2677     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.031    |
# |    n_updates        | 2476     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 8.34     |
# |    exploration_rate | 0.816    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 13       |
# |    time_elapsed     | 206      |
# |    total_timesteps  | 2716     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.252    |
# |    n_updates        | 2515     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | 8.45     |
# |    exploration_rate | 0.811    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 13       |
# |    time_elapsed     | 212      |
# |    total_timesteps  | 2792     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.109    |
# |    n_updates        | 2591     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 8.24     |
# |    exploration_rate | 0.81     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 13       |
# |    time_elapsed     | 213      |
# |    total_timesteps  | 2807     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.387    |
# |    n_updates        | 2606     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 8.35     |
# |    exploration_rate | 0.805    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 13       |
# |    time_elapsed     | 218      |
# |    total_timesteps  | 2869     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.256    |
# |    n_updates        | 2668     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 8.22     |
# |    exploration_rate | 0.804    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 13       |
# |    time_elapsed     | 220      |
# |    total_timesteps  | 2893     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.191    |
# |    n_updates        | 2692     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 8.22     |
# |    exploration_rate | 0.801    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 13       |
# |    time_elapsed     | 223      |
# |    total_timesteps  | 2936     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.337    |
# |    n_updates        | 2735     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.8     |
# |    ep_rew_mean      | 8.14     |
# |    exploration_rate | 0.799    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 13       |
# |    time_elapsed     | 225      |
# |    total_timesteps  | 2968     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.186    |
# |    n_updates        | 2767     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 8.01     |
# |    exploration_rate | 0.797    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 13       |
# |    time_elapsed     | 227      |
# |    total_timesteps  | 2989     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.086    |
# |    n_updates        | 2788     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 8.25     |
# |    exploration_rate | 0.793    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 13       |
# |    time_elapsed     | 231      |
# |    total_timesteps  | 3050     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.374    |
# |    n_updates        | 2849     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 8.16     |
# |    exploration_rate | 0.788    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 13       |
# |    time_elapsed     | 236      |
# |    total_timesteps  | 3117     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.201    |
# |    n_updates        | 2916     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 8.36     |
# |    exploration_rate | 0.784    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 13       |
# |    time_elapsed     | 242      |
# |    total_timesteps  | 3181     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.307    |
# |    n_updates        | 2980     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 8.38     |
# |    exploration_rate | 0.78     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 13       |
# |    time_elapsed     | 247      |
# |    total_timesteps  | 3239     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.351    |
# |    n_updates        | 3038     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 8.23     |
# |    exploration_rate | 0.777    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 13       |
# |    time_elapsed     | 252      |
# |    total_timesteps  | 3285     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.296    |
# |    n_updates        | 3084     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | 8.51     |
# |    exploration_rate | 0.772    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 12       |
# |    time_elapsed     | 258      |
# |    total_timesteps  | 3358     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.296    |
# |    n_updates        | 3157     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.7     |
# |    ep_rew_mean      | 8.84     |
# |    exploration_rate | 0.766    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 12       |
# |    time_elapsed     | 267      |
# |    total_timesteps  | 3449     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.205    |
# |    n_updates        | 3248     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.9     |
# |    ep_rew_mean      | 8.99     |
# |    exploration_rate | 0.763    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 12       |
# |    time_elapsed     | 271      |
# |    total_timesteps  | 3491     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.115    |
# |    n_updates        | 3290     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.7     |
# |    ep_rew_mean      | 8.86     |
# |    exploration_rate | 0.759    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 12       |
# |    time_elapsed     | 276      |
# |    total_timesteps  | 3546     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.247    |
# |    n_updates        | 3345     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.8     |
# |    ep_rew_mean      | 8.91     |
# |    exploration_rate | 0.757    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 12       |
# |    time_elapsed     | 279      |
# |    total_timesteps  | 3586     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.395    |
# |    n_updates        | 3385     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.7     |
# |    ep_rew_mean      | 8.86     |
# |    exploration_rate | 0.753    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 12       |
# |    time_elapsed     | 283      |
# |    total_timesteps  | 3637     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.39     |
# |    n_updates        | 3436     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.8     |
# |    ep_rew_mean      | 8.97     |
# |    exploration_rate | 0.75     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 12       |
# |    time_elapsed     | 287      |
# |    total_timesteps  | 3681     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.192    |
# |    n_updates        | 3480     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.9     |
# |    ep_rew_mean      | 9.02     |
# |    exploration_rate | 0.748    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 12       |
# |    time_elapsed     | 290      |
# |    total_timesteps  | 3718     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.215    |
# |    n_updates        | 3517     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12       |
# |    ep_rew_mean      | 9.1      |
# |    exploration_rate | 0.744    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 12       |
# |    time_elapsed     | 296      |
# |    total_timesteps  | 3775     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.159    |
# |    n_updates        | 3574     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.1     |
# |    ep_rew_mean      | 9.18     |
# |    exploration_rate | 0.739    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 12       |
# |    time_elapsed     | 303      |
# |    total_timesteps  | 3845     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.298    |
# |    n_updates        | 3644     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.5     |
# |    ep_rew_mean      | 9.52     |
# |    exploration_rate | 0.735    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 12       |
# |    time_elapsed     | 310      |
# |    total_timesteps  | 3912     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0931   |
# |    n_updates        | 3711     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 9.93     |
# |    exploration_rate | 0.73     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 12       |
# |    time_elapsed     | 316      |
# |    total_timesteps  | 3981     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.168    |
# |    n_updates        | 3780     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | 9.93     |
# |    exploration_rate | 0.727    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 12       |
# |    time_elapsed     | 321      |
# |    total_timesteps  | 4023     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.264    |
# |    n_updates        | 3822     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 9.79     |
# |    exploration_rate | 0.723    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 12       |
# |    time_elapsed     | 326      |
# |    total_timesteps  | 4080     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0576   |
# |    n_updates        | 3879     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 9.91     |
# |    exploration_rate | 0.721    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 12       |
# |    time_elapsed     | 328      |
# |    total_timesteps  | 4109     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.105    |
# |    n_updates        | 3908     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 9.76     |
# |    exploration_rate | 0.718    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 12       |
# |    time_elapsed     | 332      |
# |    total_timesteps  | 4157     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.204    |
# |    n_updates        | 3956     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 9.91     |
# |    exploration_rate | 0.715    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 12       |
# |    time_elapsed     | 336      |
# |    total_timesteps  | 4196     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.275    |
# |    n_updates        | 3995     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | 9.97     |
# |    exploration_rate | 0.712    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 12       |
# |    time_elapsed     | 340      |
# |    total_timesteps  | 4246     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.141    |
# |    n_updates        | 4045     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.3     |
# |    ep_rew_mean      | 10.1     |
# |    exploration_rate | 0.709    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 12       |
# |    time_elapsed     | 344      |
# |    total_timesteps  | 4295     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.172    |
# |    n_updates        | 4094     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.703    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 12       |
# |    time_elapsed     | 352      |
# |    total_timesteps  | 4384     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.208    |
# |    n_updates        | 4183     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# ...
# |    time_elapsed     | 1409     |
# |    total_timesteps  | 17082    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0411   |
# |    n_updates        | 16881    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.1     |
# |    ep_rew_mean      | 18.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1076     |
# |    fps              | 12       |
# |    time_elapsed     | 1413     |
# |    total_timesteps  | 17129    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.153    |
# |    n_updates        | 16928    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.8     |
# |    ep_rew_mean      | 18.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1080     |
# |    fps              | 12       |
# |    time_elapsed     | 1420     |
# |    total_timesteps  | 17204    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0223   |
# |    n_updates        | 17003    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23       |
# |    ep_rew_mean      | 18.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1084     |
# |    fps              | 12       |
# |    time_elapsed     | 1429     |
# |    total_timesteps  | 17302    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.015    |
# |    n_updates        | 17101    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.7     |
# |    ep_rew_mean      | 18.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1088     |
# |    fps              | 12       |
# |    time_elapsed     | 1437     |
# |    total_timesteps  | 17380    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0172   |
# |    n_updates        | 17179    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.8     |
# |    ep_rew_mean      | 18.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1092     |
# |    fps              | 12       |
# |    time_elapsed     | 1448     |
# |    total_timesteps  | 17494    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.102    |
# |    n_updates        | 17293    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.2     |
# |    ep_rew_mean      | 18.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1096     |
# |    fps              | 12       |
# |    time_elapsed     | 1459     |
# |    total_timesteps  | 17614    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.312    |
# |    n_updates        | 17413    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.1     |
# |    ep_rew_mean      | 18.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1100     |
# |    fps              | 12       |
# |    time_elapsed     | 1470     |
# |    total_timesteps  | 17717    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0996   |
# |    n_updates        | 17516    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.3     |
# |    ep_rew_mean      | 18.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1104     |
# |    fps              | 12       |
# |    time_elapsed     | 1480     |
# |    total_timesteps  | 17829    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.026    |
# |    n_updates        | 17628    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.2     |
# |    ep_rew_mean      | 18.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1108     |
# |    fps              | 12       |
# |    time_elapsed     | 1489     |
# |    total_timesteps  | 17927    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0383   |
# |    n_updates        | 17726    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23       |
# |    ep_rew_mean      | 18.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1112     |
# |    fps              | 12       |
# |    time_elapsed     | 1497     |
# |    total_timesteps  | 18023    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.153    |
# |    n_updates        | 17822    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.9     |
# |    ep_rew_mean      | 18.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1116     |
# |    fps              | 12       |
# |    time_elapsed     | 1506     |
# |    total_timesteps  | 18119    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.011    |
# |    n_updates        | 17918    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.5     |
# |    ep_rew_mean      | 18.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1120     |
# |    fps              | 12       |
# |    time_elapsed     | 1515     |
# |    total_timesteps  | 18234    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.135    |
# |    n_updates        | 18033    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.4     |
# |    ep_rew_mean      | 18.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1124     |
# |    fps              | 12       |
# |    time_elapsed     | 1522     |
# |    total_timesteps  | 18318    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.049    |
# |    n_updates        | 18117    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.3     |
# |    ep_rew_mean      | 18.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1128     |
# |    fps              | 12       |
# |    time_elapsed     | 1529     |
# |    total_timesteps  | 18403    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.113    |
# |    n_updates        | 18202    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.1     |
# |    ep_rew_mean      | 18.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1132     |
# |    fps              | 12       |
# |    time_elapsed     | 1537     |
# |    total_timesteps  | 18499    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.453    |
# |    n_updates        | 18298    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23       |
# |    ep_rew_mean      | 18.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1136     |
# |    fps              | 12       |
# |    time_elapsed     | 1547     |
# |    total_timesteps  | 18609    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0591   |
# |    n_updates        | 18408    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.3     |
# |    ep_rew_mean      | 18.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1140     |
# |    fps              | 12       |
# |    time_elapsed     | 1557     |
# |    total_timesteps  | 18729    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0237   |
# |    n_updates        | 18528    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.5     |
# |    ep_rew_mean      | 18.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1144     |
# |    fps              | 12       |
# |    time_elapsed     | 1565     |
# |    total_timesteps  | 18822    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.111    |
# |    n_updates        | 18621    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24       |
# |    ep_rew_mean      | 19.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1148     |
# |    fps              | 12       |
# |    time_elapsed     | 1574     |
# |    total_timesteps  | 18932    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0266   |
# |    n_updates        | 18731    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.1     |
# |    ep_rew_mean      | 19.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1152     |
# |    fps              | 12       |
# |    time_elapsed     | 1581     |
# |    total_timesteps  | 19004    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0881   |
# |    n_updates        | 18803    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.1     |
# |    ep_rew_mean      | 19.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1156     |
# |    fps              | 12       |
# |    time_elapsed     | 1588     |
# |    total_timesteps  | 19098    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0933   |
# |    n_updates        | 18897    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.2     |
# |    ep_rew_mean      | 19.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1160     |
# |    fps              | 12       |
# |    time_elapsed     | 1597     |
# |    total_timesteps  | 19204    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0477   |
# |    n_updates        | 19003    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.5     |
# |    ep_rew_mean      | 19.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1164     |
# |    fps              | 12       |
# |    time_elapsed     | 1606     |
# |    total_timesteps  | 19309    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.101    |
# |    n_updates        | 19108    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.9     |
# |    ep_rew_mean      | 19.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1168     |
# |    fps              | 12       |
# |    time_elapsed     | 1611     |
# |    total_timesteps  | 19372    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0988   |
# |    n_updates        | 19171    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.9     |
# |    ep_rew_mean      | 19.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1172     |
# |    fps              | 12       |
# |    time_elapsed     | 1619     |
# |    total_timesteps  | 19475    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0162   |
# |    n_updates        | 19274    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.2     |
# |    ep_rew_mean      | 19.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1176     |
# |    fps              | 12       |
# |    time_elapsed     | 1626     |
# |    total_timesteps  | 19553    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0971   |
# |    n_updates        | 19352    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.3     |
# |    ep_rew_mean      | 19.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1180     |
# |    fps              | 12       |
# |    time_elapsed     | 1632     |
# |    total_timesteps  | 19633    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0283   |
# |    n_updates        | 19432    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.4     |
# |    ep_rew_mean      | 19.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1184     |
# |    fps              | 12       |
# |    time_elapsed     | 1642     |
# |    total_timesteps  | 19747    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0366   |
# |    n_updates        | 19546    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.5     |
# |    ep_rew_mean      | 19.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1188     |
# |    fps              | 12       |
# |    time_elapsed     | 1649     |
# |    total_timesteps  | 19833    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0335   |
# |    n_updates        | 19632    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.2     |
# |    ep_rew_mean      | 19.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1192     |
# |    fps              | 12       |
# |    time_elapsed     | 1657     |
# |    total_timesteps  | 19912    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.137    |
# |    n_updates        | 19711    |
# ----------------------------------

# %%
from stable_baselines3 import DQN
import pprint
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# ## Testing
#
# Visualize a few episodes

# %%
video_folder = "videos"
model_name = "dqn_model_cnn"
model_fast = DQN.load('highway_cnn/model')
env = gym.make('highway-fast-v0', render_mode='rgb_array')
# Use RecordVideo wrapper to record videos in the specified folder
video_path = f"{video_folder}/{model_name}"
env = RecordVideo(env, video_folder=video_path, episode_trigger=lambda ep: True)
for episode in trange(3, desc='Test episodes'):
    (obs, info), done = env.reset(), False
    while not done:
        
        action, _ = model_fast.predict(obs, deterministic=True)
        obs, reward, done, truncated, info = env.step(int(action))
env.close()
show_videos()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 3
#       1 video_folder = "videos"
#       2 model_name = "dqn_model_cnn"
# ----> 3 model_fast = DQN.load('highway_cnn/model')
#       4 env = gym.make('highway-fast-v0', render_mode='rgb_array')
#       5 # Use RecordVideo wrapper to record videos in the specified folder
#
# File ~/.local/lib/python3.8/site-packages/stable_baselines3/common/base_class.py:744, in BaseAlgorithm.load(cls, path, env, device, custom_objects, print_system_info, force_reset, **kwargs)
#     741 try:
#     742     # put state_dicts back in place
#     743     model.set_parameters(params, exact_match=True, device=device)
# --> 744 except RuntimeError as e:
#     745     # Patch to load policies saved using SB3 < 1.7.0
#     746     # the error is probably due to old policy being loaded
#     747     # See https://github.com/DLR-RM/stable-baselines3/issues/1233
#     748     if "pi_features_extractor" in str(e) and "Missing key(s) in state_dict" in str(e):
#     749         model.set_parameters(params, exact_match=False, device=device)
#
# File ~/.local/lib/python3.8/site-packages/stable_baselines3/common/base_class.py:629, in BaseAlgorithm.set_parameters(self, load_path_or_dict, exact_match, device)
#     611     raise ValueError(f"Key {name} is an invalid object name.") from e
#     613 if isinstance(attr, th.optim.Optimizer):
#     614     # Optimizers do not support "strict" keyword...
#     615     # Seems like they will just replace the whole
#    (...)
#     627     # Solution: Just load the state-dict as is, and trust
#     628     # the user has provided a sensible state dictionary.
# --> 629     attr.load_state_dict(params[name])  # type: ignore[arg-type]
#     630 else:
#     631     # Assume attr is th.nn.Module
#     632     attr.load_state_dict(params[name], strict=exact_match)
#
# File ~/.local/lib/python3.8/site-packages/torch/_compile.py:24, in _disable_dynamo.<locals>.inner(*args, **kwargs)
#      20 @functools.wraps(fn)
#      21 def inner(*args, **kwargs):
#      22     import torch._dynamo
# ---> 24     return torch._dynamo.disable(fn, recursive)(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/torch/_dynamo/eval_frame.py:489, in _TorchDynamoContext.__call__.<locals>._fn(*args, **kwargs)
#     487     dynamo_config_ctx.__enter__()
#     488 try:
# --> 489     return fn(*args, **kwargs)
#     490 finally:
#     491     set_eval_frame(prior)
#
# File ~/.local/lib/python3.8/site-packages/torch/optim/optimizer.py:747, in Optimizer.load_state_dict(self, state_dict)
#     745 saved_lens = (len(g['params']) for g in saved_groups)
#     746 if any(p_len != s_len for p_len, s_len in zip(param_lens, saved_lens)):
# --> 747     raise ValueError("loaded state dict contains a parameter group "
#     748                      "that doesn't match the size of optimizer's group")
#     750 # Update the state
#     751 id_map = dict(zip(chain.from_iterable(g['params'] for g in saved_groups),
#     752               chain.from_iterable(g['params'] for g in groups)))
#
# ValueError: loaded state dict contains a parameter group that doesn't match the size of optimizer's group
